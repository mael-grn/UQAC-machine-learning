# %% [markdown]
# ## Exemple d'un utilitaire pour nettoyer les valeus manquantes

# %%
#importation du jeu données. dataset
import pandas as pd
pd.options.display.float_format='{:.2f}'.format
df = pd.read_csv('FraudeAssuranceAuto.csv')
df.head(10)
# Out:
#    ID Insurance Type   Income of Policy Holder Marital Status  Num Claimants  \
# 0   1              CI                        0            NaN              2
# 1   2              CI                        0            NaN              2
# 2   3              CI                    54613        Married              1
# 3   4              CI                        0            NaN              3
# 4   5              CI                        0            NaN              4
# 5   6              CI                        0            NaN              1
# 6   7              CI                    52567         Single              3
# 7   8              CI                        0            NaN              2
# 8   9              CI                        0            NaN              1
# 9  10              CI                    42300        Married              4
#
#    Injury Type Overnight Hospital Stay  Claim Amount  Total Claimed  \
# 0  Soft Tissue                      No          1625           3250
# 1         Back                     Yes         15028          60112
# 2  Broken Limb                      No        -99999              0
# 3      Serious                     Yes        270200              0
# 4  Soft Tissue                      No          8869              0
# 5  Broken Limb                     Yes         17480              0
# 6  Broken Limb                      No          3017          18102
# 7         Back                     Yes          7463              0
# 8  Soft Tissue                      No          2067              0
# 9         Back                      No          2260              0
#
#    Num Claims  Num Soft Tissue  % Soft Tissue  Claim Amount Received  \
# 0           2             2.00           1.00                      0
# 1           1             0.00           0.00                  15028
# 2           0             0.00           0.00                    572
# 3           0             0.00           0.00                 270200
# 4           0             0.00           0.00                      0
# 5           0             0.00           0.00                  17480
# 6           2             1.00           0.50                      0
# 7           0             0.00           0.00                   7463
# 8           0              NaN           0.00                   2067
# 9           0             0.00           0.00                   2260
#
#    Fraud Flag
# 0           1
# 1           0
# 2           0
# 3           0
# 4           1
# 5           0
# 6           1
# 7           0
# 8           0
# 9           0

# %%
df.describe(include="all")
# Out:
#            ID Insurance Type   Income of Policy Holder Marital Status  \
# count  500.00             500                   500.00            170
# unique    NaN               1                      NaN              3
# top       NaN              CI                      NaN        Married
# freq      NaN             500                      NaN             99
# mean   250.50             NaN                 13739.99            NaN
# std    144.48             NaN                 20081.54            NaN
# min      1.00             NaN                     0.00            NaN
# 25%    125.75             NaN                     0.00            NaN
# 50%    250.50             NaN                     0.00            NaN
# 75%    375.25             NaN                 33918.50            NaN
# max    500.00             NaN                 71284.00            NaN
#
#         Num Claimants  Injury Type Overnight Hospital Stay  Claim Amount  \
# count          500.00          500                     500        500.00
# unique            NaN            4                       2           NaN
# top               NaN  Broken Limb                      No           NaN
# freq              NaN          177                     354           NaN
# mean             1.91          NaN                     NaN      16373.20
# std              1.01          NaN                     NaN      29426.28
# min              1.00          NaN                     NaN     -99999.00
# 25%              1.00          NaN                     NaN       3322.25
# 50%              2.00          NaN                     NaN       5663.00
# 75%              3.00          NaN                     NaN      12245.50
# max              4.00          NaN                     NaN     270200.00
#
#         Total Claimed  Num Claims  Num Soft Tissue  % Soft Tissue  \
# count          500.00      500.00           490.00         500.00
# unique            NaN         NaN              NaN            NaN
# top               NaN         NaN              NaN            NaN
# freq              NaN         NaN              NaN            NaN
# mean          9597.19        0.80             0.23           0.17
# std          35655.69        2.67             0.59           0.43
# min              0.00        0.00             0.00           0.00
# 25%              0.00        0.00             0.00           0.00
# 50%              0.00        0.00             0.00           0.00
# 75%          11282.75        1.00             0.00           0.00
# max         729792.00       56.00             5.00           2.00
#
#         Claim Amount Received  Fraud Flag
# count                  500.00      500.00
# unique                    NaN         NaN
# top                       NaN         NaN
# freq                      NaN         NaN
# mean                 13051.94        0.34
# std                  30547.19        0.47
# min                      0.00        0.00
# 25%                      0.00        0.00
# 50%                   3253.50        0.00
# 75%                   8191.75        1.00
# max                 295303.00        1.00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       500 non-null    int64
#  1   Insurance Type           500 non-null    object
#  2   Income of Policy Holder  500 non-null    int64
#  3   Marital Status           170 non-null    object
#  4   Num Claimants            500 non-null    int64
#  5   Injury Type              500 non-null    object
#  6   Overnight Hospital Stay  500 non-null    object
#  7   Claim Amount             500 non-null    int64
#  8   Total Claimed            500 non-null    int64
#  9   Num Claims               500 non-null    int64
#  10  Num Soft Tissue          490 non-null    float64
#  11  % Soft Tissue            500 non-null    float64
#  12  Claim Amount Received    500 non-null    int64
#  13  Fraud Flag               500 non-null    int64
# dtypes: float64(2), int64(8), object(4)
# memory usage: 54.8+ KB

# %% [markdown]
# ## scikit-learn fournit une classe bien pratique pour gérer les données manquantes : Imputer

# %%
#importation de l'utilitaire d'imputation
from sklearn.impute import SimpleImputer

# %%
#Voici comment l'utiliser: on doit d'abord créer une instance
# de la classe SimpleImputer, en sépcifiant que vous voulez remplacer
#les valeurs manquantes désignées par le symbole NaN : Not a Number
#de chaque caractéristique. la stratégie de remplacement est la moyenne
#L'instanciation de la classe SimpleImputer permet de définir un objet transformateur.

imp = SimpleImputer(strategy='mean')

# %%
#la moyenne "mean" pouvant être calculée uniquement sur des variables
#numérique. Nous devons créer une copie des données en éliminant
#les caractéristiques catégorielle (de type object)

v_cat = ['Insurance Type ','Marital Status','Injury Type','Overnight Hospital Stay']
df_num = df.drop(columns=v_cat, axis=1)

# %%
#mantenant on peut appliquer l'instance SimpleImputer 
#au jeu de données -TBA- d'entrainement  en utilisant la méthode fit()
# fit() permet juste une estimation de la moyenne de chaque variable mais le dataframe (données) n'est pas affecté
imp.fit(df_num)
# Out:
# SimpleImputer()

# %%
#le fit du SimpleImputer a simplement calculé la moyenne de chaque caractéristique
# et a rangé le résultat dans sa variable d'instance statistics_
imp.statistics_
# Out:
# array([2.50500000e+02, 1.37399940e+04, 1.90800000e+00, 1.63732040e+04,
#        9.59718600e+03, 7.98000000e-01, 2.34693878e-01, 1.72011905e-01,
#        1.30519420e+04, 3.36000000e-01])

# %%
df_num.mean().values
# Out:
# array([2.50500000e+02, 1.37399940e+04, 1.90800000e+00, 1.63732040e+04,
#        9.59718600e+03, 7.98000000e-01, 2.34693878e-01, 1.72011905e-01,
#        1.30519420e+04, 3.36000000e-01])

# %%
#mainteant vous pouvez utiliser cet "SimpleImputer" entraîné pour transformer
#le jeu d'entrainement en remplacant les valeurs manquantes par les moyennes
#apprises
X_num= imp.transform(df_num)

# %%
#le résultat X_num est un tableau Numpy complet constitué des valeurs transformés
#si vous voulez re-injecter dans un dataframe Pandas:
df_fraude_aa_num=pd.DataFrame(X_num, columns=df_num.columns)
df_fraude_aa_num.head(10)
# Out:
#      ID  Income of Policy Holder  Num Claimants  Claim Amount  Total Claimed  \
# 0  1.00                     0.00           2.00       1625.00        3250.00
# 1  2.00                     0.00           2.00      15028.00       60112.00
# 2  3.00                 54613.00           1.00     -99999.00           0.00
# 3  4.00                     0.00           3.00     270200.00           0.00
# 4  5.00                     0.00           4.00       8869.00           0.00
# 5  6.00                     0.00           1.00      17480.00           0.00
# 6  7.00                 52567.00           3.00       3017.00       18102.00
# 7  8.00                     0.00           2.00       7463.00           0.00
# 8  9.00                     0.00           1.00       2067.00           0.00
# 9 10.00                 42300.00           4.00       2260.00           0.00
#
#    Num Claims  Num Soft Tissue  % Soft Tissue  Claim Amount Received  \
# 0        2.00             2.00           1.00                   0.00
# 1        1.00             0.00           0.00               15028.00
# 2        0.00             0.00           0.00                 572.00
# 3        0.00             0.00           0.00              270200.00
# 4        0.00             0.00           0.00                   0.00
# 5        0.00             0.00           0.00               17480.00
# 6        2.00             1.00           0.50                   0.00
# 7        0.00             0.00           0.00                7463.00
# 8        0.00             0.23           0.00                2067.00
# 9        0.00             0.00           0.00                2260.00
#
#    Fraud Flag
# 0        1.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4        1.00
# 5        0.00
# 6        1.00
# 7        0.00
# 8        0.00
# 9        0.00

# %%
df_fraude_aa_num.describe(include="all")
# Out:
#           ID  Income of Policy Holder  Num Claimants  Claim Amount  \
# count 500.00                   500.00         500.00        500.00
# mean  250.50                 13739.99           1.91      16373.20
# std   144.48                 20081.54           1.01      29426.28
# min     1.00                     0.00           1.00     -99999.00
# 25%   125.75                     0.00           1.00       3322.25
# 50%   250.50                     0.00           2.00       5663.00
# 75%   375.25                 33918.50           3.00      12245.50
# max   500.00                 71284.00           4.00     270200.00
#
#        Total Claimed  Num Claims  Num Soft Tissue  % Soft Tissue  \
# count         500.00      500.00           500.00         500.00
# mean         9597.19        0.80             0.23           0.17
# std         35655.69        2.67             0.58           0.43
# min             0.00        0.00             0.00           0.00
# 25%             0.00        0.00             0.00           0.00
# 50%             0.00        0.00             0.00           0.00
# 75%         11282.75        1.00             0.00           0.00
# max        729792.00       56.00             5.00           2.00
#
#        Claim Amount Received  Fraud Flag
# count                 500.00      500.00
# mean                13051.94        0.34
# std                 30547.19        0.47
# min                     0.00        0.00
# 25%                     0.00        0.00
# 50%                  3253.50        0.00
# 75%                  8191.75        1.00
# max                295303.00        1.00

# %%
#Nous avons appliquer l'imputation uniquement aux caractéristiques
#numériques. Nous allons le faire pour les varaibles qualitatives
#Nous allons récupérer une copie des données qualitatives
df_cat=df[v_cat]

# %%
df_cat.head()
# Out:
#   Insurance Type  Marital Status  Injury Type Overnight Hospital Stay
# 0              CI            NaN  Soft Tissue                      No
# 1              CI            NaN         Back                     Yes
# 2              CI        Married  Broken Limb                      No
# 3              CI            NaN      Serious                     Yes
# 4              CI            NaN  Soft Tissue                      No

# %%
#nous utiliserons le mode : valeur la plus fréquente pour 
#remplacer les valeurs manquantes
imp=SimpleImputer(strategy='most_frequent')

# %%
imp.fit(df_cat)
# Out:
# SimpleImputer(strategy='most_frequent')

# %%
X_cat=imp.transform(df_cat)

# %%
df_fraude_aa_cat=pd.DataFrame(X_cat, columns=df_cat.columns)

# %%
df_fraude_aa_cat.describe(include='all')
# Out:
#        Insurance Type  Marital Status  Injury Type Overnight Hospital Stay
# count              500            500          500                     500
# unique               1              3            4                       2
# top                 CI        Married  Broken Limb                      No
# freq               500            429          177                     354

# %%
df_fraude_aa_cat.shape
# Out:
# (500, 4)

# %%
#pour produir le dataFrame final nous allons concatener les deux dataframes
#contenant respectivement les données de type numérique et le type catégoriel
df_fraude_aa=pd.concat([df_fraude_aa_num,df_fraude_aa_cat], axis=1)

# %%
df_fraude_aa
# Out:
#         ID  Income of Policy Holder  Num Claimants  Claim Amount  \
# 0      1.0                      0.0            2.0        1625.0
# 1      2.0                      0.0            2.0       15028.0
# 2      3.0                  54613.0            1.0      -99999.0
# 3      4.0                      0.0            3.0      270200.0
# 4      5.0                      0.0            4.0        8869.0
# ..     ...                      ...            ...           ...
# 495  496.0                      0.0            1.0        2118.0
# 496  497.0                  29280.0            4.0        3199.0
# 497  498.0                      0.0            1.0       32469.0
# 498  499.0                  46683.0            1.0      179448.0
# 499  500.0                      0.0            1.0        8259.0
#
#      Total Claimed  Num Claims  Num Soft Tissue  % Soft Tissue  \
# 0           3250.0         2.0         2.000000            1.0
# 1          60112.0         1.0         0.000000            0.0
# 2              0.0         0.0         0.000000            0.0
# 3              0.0         0.0         0.000000            0.0
# 4              0.0         0.0         0.000000            0.0
# ..             ...         ...              ...            ...
# 495            0.0         0.0         0.000000            0.0
# 496            0.0         0.0         0.234694            0.0
# 497            0.0         0.0         0.000000            0.0
# 498            0.0         0.0         0.000000            0.0
# 499            0.0         0.0         0.000000            0.0
#
#      Claim Amount Received  Fraud Flag Insurance Type  Marital Status  \
# 0                      0.0         1.0              CI        Married
# 1                  15028.0         0.0              CI        Married
# 2                    572.0         0.0              CI        Married
# 3                 270200.0         0.0              CI        Married
# 4                      0.0         1.0              CI        Married
# ..                     ...         ...             ...            ...
# 495                    0.0         1.0              CI        Married
# 496                    0.0         1.0              CI        Married
# 497                16763.0         0.0              CI        Married
# 498               179448.0         0.0              CI        Married
# 499                    0.0         1.0              CI        Married
#
#      Injury Type Overnight Hospital Stay
# 0    Soft Tissue                      No
# 1           Back                     Yes
# 2    Broken Limb                      No
# 3        Serious                     Yes
# 4    Soft Tissue                      No
# ..           ...                     ...
# 495  Soft Tissue                      No
# 496  Broken Limb                     Yes
# 497  Broken Limb                     Yes
# 498  Broken Limb                      No
# 499  Broken Limb                      No
#
# [500 rows x 14 columns]

# %%
df_fraude_aa.shape
# Out:
# (500, 14)
